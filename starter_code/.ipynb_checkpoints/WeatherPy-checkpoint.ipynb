# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing dependencies
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from citipy import citipy
import numpy as np
from api_keys import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# Generating random Cities list
lat_lngs = []
cities = []

lat = np.random.uniform(-90,90,1500) 
lng = np.random.uniform(-180,180,1500)
lat_lngs = zip(lat, lng)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Performing API call
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'metric'
query_url = f'{url}appid={weather_api_key}&units={units}&q='

# %%
# Creating lists 
city_list = []
lat = []
lng = []
max_temp = []
humidity = []
cloud = []
wind_speed = []
country = []
date = []

# Creating record count and set count
count = 0
set_count = 1

print(f'Beginning Data Retrieval')
print(f'-----------------------------')

# Looping through API to retrieve info of each city
for city in cities:
    
    response = requests.get(query_url + city.replace(' ','&')).json()
    
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        if count < 50:
            count = count + 1
            city_list.append(city)
        else: 
            set_count = set_count + 1
            count = 0
            city_list.append(city)
        print(f'Processing Record {count} of Set {set_count} | {city}')
    except:
        print(f'City not found. Skipping...')
print(f'------------------------------')
print(f'Data Retrieval Complete')
print(f'------------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | kabalo
# Processing Record 8 of Set 1 | suoyarvi
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | atar
# Processing Record 11 of Set 1 | chinchani
# Processing Record 12 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 13 of Set 1 | srandakan
# Processing Record 14 of Set 1 | comodoro rivadavia
# Processing Record 15 of Set 1 | metro
# Processing Record 16 of Set 1 | prikubanskiy
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | ushtobe
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | prince rupert
# Processing Record 25 of Set 1 | machiques
# Processing Record 26 of Set 1 | bima
# City not found. Skipping...
# Processing Record 27 of Set 1 | kirakira
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | merauke
# Processing Record 30 of Set 1 | naryan-mar
# Processing Record 31 of Set 1 | mineiros
# Processing Record 32 of Set 1 | omboue
# Processing Record 33 of Set 1 | najran
# Processing Record 34 of Set 1 | alice springs
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 1 | clyde river
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 1 | sao joao da barra
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | orocue
# Processing Record 40 of Set 1 | guerrero negro
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | gariaband
# Processing Record 43 of Set 1 | tuatapere
# City not found. Skipping...
# Processing Record 44 of Set 1 | lorengau
# Processing Record 45 of Set 1 | ancud
# City not found. Skipping...
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | riyadh
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | caborca
# Processing Record 0 of Set 2 | juneau
# Processing Record 1 of Set 2 | severo-kurilsk
# City not found. Skipping...
# Processing Record 2 of Set 2 | berlevag
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | shihezi
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | yulara
# City not found. Skipping...
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | tres arroyos
# Processing Record 12 of Set 2 | enkoping
# Processing Record 13 of Set 2 | saint-joseph
# Processing Record 14 of Set 2 | chapala
# Processing Record 15 of Set 2 | ilo
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | port lincoln
# Processing Record 18 of Set 2 | vao
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | laguna
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | willowmore
# Processing Record 24 of Set 2 | pangnirtung
# Processing Record 25 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 26 of Set 2 | angoche
# City not found. Skipping...
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | yebaishou
# City not found. Skipping...
# Processing Record 29 of Set 2 | hamilton
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | ust-koksa
# City not found. Skipping...
# Processing Record 34 of Set 2 | san andres
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | vardo
# Processing Record 37 of Set 2 | hambantota
# Processing Record 38 of Set 2 | harboore
# City not found. Skipping...
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | esperance
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | kungurtug
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | lianzhou
# Processing Record 49 of Set 2 | ostrovnoy
# Processing Record 50 of Set 2 | flinders
# Processing Record 0 of Set 3 | atasu
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | hauterive
# Processing Record 5 of Set 3 | broome
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | padang
# Processing Record 8 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | port alfred
# Processing Record 11 of Set 3 | bartica
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | mys shmidta
# Processing Record 14 of Set 3 | eirunepe
# Processing Record 15 of Set 3 | sulangan
# Processing Record 16 of Set 3 | deputatskiy
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | chokurdakh
# City not found. Skipping...
# Processing Record 19 of Set 3 | arman
# Processing Record 20 of Set 3 | kahului
# Processing Record 21 of Set 3 | jieshi
# Processing Record 22 of Set 3 | north bend
# Processing Record 23 of Set 3 | havre-saint-pierre
# Processing Record 24 of Set 3 | bathsheba
# Processing Record 25 of Set 3 | kalmunai
# Processing Record 26 of Set 3 | spring valley
# City not found. Skipping...
# Processing Record 27 of Set 3 | pandamatenga
# Processing Record 28 of Set 3 | ribeira grande
# Processing Record 29 of Set 3 | kununurra
# Processing Record 30 of Set 3 | skovorodino
# Processing Record 31 of Set 3 | rocky mountain house
# Processing Record 32 of Set 3 | bandarbeyla
# Processing Record 33 of Set 3 | tongliao
# Processing Record 34 of Set 3 | tocopilla
# Processing Record 35 of Set 3 | abu samrah
# Processing Record 36 of Set 3 | komsomolskiy
# Processing Record 37 of Set 3 | grua
# Processing Record 38 of Set 3 | hofn
# Processing Record 39 of Set 3 | hualmay
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | grand river south east
# Processing Record 43 of Set 3 | fort nelson
# Processing Record 44 of Set 3 | poum
# Processing Record 45 of Set 3 | zlobin
# Processing Record 46 of Set 3 | arlit
# Processing Record 47 of Set 3 | scottsbluff
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | lingao
# Processing Record 50 of Set 3 | upernavik
# Processing Record 0 of Set 4 | klaksvik
# Processing Record 1 of Set 4 | stornoway
# Processing Record 2 of Set 4 | manokwari
# City not found. Skipping...
# Processing Record 3 of Set 4 | mangan
# Processing Record 4 of Set 4 | sampit
# Processing Record 5 of Set 4 | malhador
# Processing Record 6 of Set 4 | santa isabel do rio negro
# Processing Record 7 of Set 4 | ust-nera
# City not found. Skipping...
# Processing Record 8 of Set 4 | sangmelima
# Processing Record 9 of Set 4 | chirongui
# Processing Record 10 of Set 4 | fairbanks
# Processing Record 11 of Set 4 | vila
# Processing Record 12 of Set 4 | saint-philippe
# City not found. Skipping...
# Processing Record 13 of Set 4 | high level
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | rocha
# Processing Record 16 of Set 4 | luwuk
# Processing Record 17 of Set 4 | astana
# Processing Record 18 of Set 4 | sabang
# Processing Record 19 of Set 4 | vidalia
# Processing Record 20 of Set 4 | linjiang
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | blumenau
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | puerto escondido
# Processing Record 25 of Set 4 | mayo
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | harper
# Processing Record 28 of Set 4 | sinnamary
# Processing Record 29 of Set 4 | vila franca do campo
# Processing Record 30 of Set 4 | festus
# Processing Record 31 of Set 4 | portland
# Processing Record 32 of Set 4 | pulawy
# City not found. Skipping...
# Processing Record 33 of Set 4 | nome
# City not found. Skipping...
# Processing Record 34 of Set 4 | derzhavinsk
# Processing Record 35 of Set 4 | freeport
# Processing Record 36 of Set 4 | kampot
# Processing Record 37 of Set 4 | mamit
# Processing Record 38 of Set 4 | grand gaube
# Processing Record 39 of Set 4 | southampton
# Processing Record 40 of Set 4 | birao
# Processing Record 41 of Set 4 | marzuq
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | bourail
# Processing Record 44 of Set 4 | paamiut
# Processing Record 45 of Set 4 | bombon
# Processing Record 46 of Set 4 | saint-louis
# Processing Record 47 of Set 4 | jambi
# Processing Record 48 of Set 4 | caravelas
# Processing Record 49 of Set 4 | sola
# Processing Record 50 of Set 4 | marawi
# Processing Record 0 of Set 5 | torbay
# Processing Record 1 of Set 5 | buriti alegre
# Processing Record 2 of Set 5 | haukipudas
# Processing Record 3 of Set 5 | eyl
# Processing Record 4 of Set 5 | ponta do sol
# Processing Record 5 of Set 5 | tongren
# Processing Record 6 of Set 5 | heihe
# Processing Record 7 of Set 5 | barbosa ferraz
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | meulaboh
# Processing Record 10 of Set 5 | oshawa
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | jasper
# Processing Record 13 of Set 5 | itarema
# Processing Record 14 of Set 5 | jizan
# Processing Record 15 of Set 5 | baoning
# City not found. Skipping...
# Processing Record 16 of Set 5 | nassjo
# Processing Record 17 of Set 5 | miguel hidalgo
# City not found. Skipping...
# Processing Record 18 of Set 5 | kinshasa
# Processing Record 19 of Set 5 | cidreira
# Processing Record 20 of Set 5 | toyooka
# Processing Record 21 of Set 5 | karonga
# Processing Record 22 of Set 5 | belsand
# Processing Record 23 of Set 5 | springbok
# Processing Record 24 of Set 5 | monselice
# City not found. Skipping...
# Processing Record 25 of Set 5 | wanning
# Processing Record 26 of Set 5 | nova granada
# Processing Record 27 of Set 5 | keetmanshoop
# Processing Record 28 of Set 5 | roros
# Processing Record 29 of Set 5 | sitka
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | raudeberg
# Processing Record 32 of Set 5 | polessk
# Processing Record 33 of Set 5 | biloela
# City not found. Skipping...
# Processing Record 34 of Set 5 | port lavaca
# City not found. Skipping...
# Processing Record 35 of Set 5 | harlingen
# Processing Record 36 of Set 5 | kralendijk
# Processing Record 37 of Set 5 | marathon
# Processing Record 38 of Set 5 | albert town
# Processing Record 39 of Set 5 | saldanha
# City not found. Skipping...
# Processing Record 40 of Set 5 | coruripe
# Processing Record 41 of Set 5 | haines junction
# City not found. Skipping...
# Processing Record 42 of Set 5 | basco
# Processing Record 43 of Set 5 | port-gentil
# Processing Record 44 of Set 5 | imst
# Processing Record 45 of Set 5 | lobva
# Processing Record 46 of Set 5 | sirnak
# City not found. Skipping...
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | solnechnyy
# Processing Record 49 of Set 5 | liberal
# Processing Record 50 of Set 5 | sharanga
# Processing Record 0 of Set 6 | college
# Processing Record 1 of Set 6 | belaya gora
# Processing Record 2 of Set 6 | vallenar
# Processing Record 3 of Set 6 | masuguru
# Processing Record 4 of Set 6 | praia da vitoria
# Processing Record 5 of Set 6 | banjarmasin
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | sao filipe
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | hunucma
# City not found. Skipping...
# Processing Record 10 of Set 6 | sorland
# Processing Record 11 of Set 6 | taikang
# Processing Record 12 of Set 6 | buin
# Processing Record 13 of Set 6 | kruisfontein
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 6 | prado
# Processing Record 15 of Set 6 | luanda
# Processing Record 16 of Set 6 | miraflores
# Processing Record 17 of Set 6 | mahibadhoo
# Processing Record 18 of Set 6 | vryburg
# Processing Record 19 of Set 6 | kilindoni
# Processing Record 20 of Set 6 | corowa
# Processing Record 21 of Set 6 | inhambane
# Processing Record 22 of Set 6 | sao miguel do araguaia
# Processing Record 23 of Set 6 | port elizabeth
# Processing Record 24 of Set 6 | winfield
# Processing Record 25 of Set 6 | catamarca
# Processing Record 26 of Set 6 | male
# Processing Record 27 of Set 6 | swan hill
# Processing Record 28 of Set 6 | dunda
# Processing Record 29 of Set 6 | nishihara
# Processing Record 30 of Set 6 | westport
# Processing Record 31 of Set 6 | ust-omchug
# City not found. Skipping...
# Processing Record 32 of Set 6 | lata
# Processing Record 33 of Set 6 | anadyr
# Processing Record 34 of Set 6 | constitucion
# Processing Record 35 of Set 6 | renqiu
# Processing Record 36 of Set 6 | whitehorse
# Processing Record 37 of Set 6 | saga
# Processing Record 38 of Set 6 | chifeng
# Processing Record 39 of Set 6 | dakar
# Processing Record 40 of Set 6 | ayan
# Processing Record 41 of Set 6 | cherskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | isangel
# Processing Record 43 of Set 6 | sarahan
# Processing Record 44 of Set 6 | ngaoundere
# City not found. Skipping...
# Processing Record 45 of Set 6 | ribeira brava
# Processing Record 46 of Set 6 | lagoa
# Processing Record 47 of Set 6 | bom jesus
# Processing Record 48 of Set 6 | ongandjera
# Processing Record 49 of Set 6 | san patricio
# City not found. Skipping...
# Processing Record 50 of Set 6 | vagur
# Processing Record 0 of Set 7 | zhongshu
# Processing Record 1 of Set 7 | kloulklubed
# City not found. Skipping...
# Processing Record 2 of Set 7 | minuri
# Processing Record 3 of Set 7 | tawau
# Processing Record 4 of Set 7 | hobyo
# Processing Record 5 of Set 7 | kyabram
# Processing Record 6 of Set 7 | monrovia
# Processing Record 7 of Set 7 | hervey bay
# Processing Record 8 of Set 7 | salzkotten
# City not found. Skipping...
# Processing Record 9 of Set 7 | ixtapa
# City not found. Skipping...
# Processing Record 10 of Set 7 | vanimo
# Processing Record 11 of Set 7 | maniitsoq
# Processing Record 12 of Set 7 | bend
# Processing Record 13 of Set 7 | kudahuvadhoo
# Processing Record 14 of Set 7 | hisor
# City not found. Skipping...
# Processing Record 15 of Set 7 | liwale
# Processing Record 16 of Set 7 | biak
# Processing Record 17 of Set 7 | ballina
# Processing Record 18 of Set 7 | brewster
# Processing Record 19 of Set 7 | kumano
# Processing Record 20 of Set 7 | ostersund
# City not found. Skipping...
# Processing Record 21 of Set 7 | hastings
# Processing Record 22 of Set 7 | ankang
# Processing Record 23 of Set 7 | sabha
# Processing Record 24 of Set 7 | srednekolymsk
# Processing Record 25 of Set 7 | pontianak
# Processing Record 26 of Set 7 | katangli
# Processing Record 27 of Set 7 | boras
# Processing Record 28 of Set 7 | stawell
# City not found. Skipping...
# Processing Record 29 of Set 7 | leh
# Processing Record 30 of Set 7 | bauchi
# Processing Record 31 of Set 7 | abu kamal
# Processing Record 32 of Set 7 | pastavy
# City not found. Skipping...
# Processing Record 33 of Set 7 | velikooktyabrskiy
# Processing Record 34 of Set 7 | pangody
# Processing Record 35 of Set 7 | aktau
# Processing Record 36 of Set 7 | constantine
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | baruun-urt
# Processing Record 39 of Set 7 | robertsport
# Processing Record 40 of Set 7 | mogadishu
# Processing Record 41 of Set 7 | manta
# Processing Record 42 of Set 7 | varkaus
# Processing Record 43 of Set 7 | llangefni
# Processing Record 44 of Set 7 | luquillo
# Processing Record 45 of Set 7 | faya
# Processing Record 46 of Set 7 | thompson
# Processing Record 47 of Set 7 | port hardy
# Processing Record 48 of Set 7 | bambous virieux
# Processing Record 49 of Set 7 | lima
# Processing Record 50 of Set 7 | jiuquan
# Processing Record 0 of Set 8 | takoradi
# Processing Record 1 of Set 8 | muros
# Processing Record 2 of Set 8 | fuzhou
# Processing Record 3 of Set 8 | honiara
# Processing Record 4 of Set 8 | bur gabo
# Processing Record 5 of Set 8 | toledo
# Processing Record 6 of Set 8 | wattegama
# Processing Record 7 of Set 8 | paraiso
# City not found. Skipping...
# Processing Record 8 of Set 8 | banikoara
# Processing Record 9 of Set 8 | rezh
# Processing Record 10 of Set 8 | wittenbach
# Processing Record 11 of Set 8 | saint-pierre
# Processing Record 12 of Set 8 | pyapon
# Processing Record 13 of Set 8 | kalaleh
# Processing Record 14 of Set 8 | nikolayevka
# Processing Record 15 of Set 8 | svetlogorsk
# Processing Record 16 of Set 8 | araouane
# Processing Record 17 of Set 8 | central point
# Processing Record 18 of Set 8 | fortuna
# Processing Record 19 of Set 8 | san quintin
# City not found. Skipping...
# Processing Record 20 of Set 8 | kanker
# Processing Record 21 of Set 8 | klyuchi
# City not found. Skipping...
# Processing Record 22 of Set 8 | puerto narino
# Processing Record 23 of Set 8 | tambacounda
# Processing Record 24 of Set 8 | sept-iles
# City not found. Skipping...
# Processing Record 25 of Set 8 | muravlenko
# Processing Record 26 of Set 8 | moranbah
# City not found. Skipping...
# Processing Record 27 of Set 8 | tabat
# Processing Record 28 of Set 8 | calabozo
# Processing Record 29 of Set 8 | husavik
# Processing Record 30 of Set 8 | riohacha
# Processing Record 31 of Set 8 | bonga
# Processing Record 32 of Set 8 | baracoa
# Processing Record 33 of Set 8 | clydebank
# Processing Record 34 of Set 8 | praia
# Processing Record 35 of Set 8 | canutama
# Processing Record 36 of Set 8 | muana
# Processing Record 37 of Set 8 | belmonte
# Processing Record 38 of Set 8 | kindu
# Processing Record 39 of Set 8 | cabedelo
# Processing Record 40 of Set 8 | shellbrook
# City not found. Skipping...
# Processing Record 41 of Set 8 | moba
# Processing Record 42 of Set 8 | samarai
# Processing Record 43 of Set 8 | lazaro cardenas
# Processing Record 44 of Set 8 | maarianhamina
# Processing Record 45 of Set 8 | mahanje
# Processing Record 46 of Set 8 | sorong
# Processing Record 47 of Set 8 | axim
# Processing Record 48 of Set 8 | zhigansk
# City not found. Skipping...
# Processing Record 49 of Set 8 | bundi
# Processing Record 50 of Set 8 | bedford
# Processing Record 0 of Set 9 | ocampo
# Processing Record 1 of Set 9 | aras
# Processing Record 2 of Set 9 | havre
# Processing Record 3 of Set 9 | tynda
# Processing Record 4 of Set 9 | buchanan
# Processing Record 5 of Set 9 | ola
# Processing Record 6 of Set 9 | port hedland
# Processing Record 7 of Set 9 | verkhnevilyuysk
# Processing Record 8 of Set 9 | salym
# Processing Record 9 of Set 9 | terney
# Processing Record 10 of Set 9 | poya
# Processing Record 11 of Set 9 | olinda
# Processing Record 12 of Set 9 | manono
# Processing Record 13 of Set 9 | russell
# Processing Record 14 of Set 9 | khovu-aksy
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | nanortalik
# Processing Record 17 of Set 9 | gasa
# Processing Record 18 of Set 9 | grootfontein
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 9 | vostok
# Processing Record 20 of Set 9 | brae
# Processing Record 21 of Set 9 | lerwick
# Processing Record 22 of Set 9 | xining
# Processing Record 23 of Set 9 | buraydah
# Processing Record 24 of Set 9 | provideniya
# Processing Record 25 of Set 9 | santa fe
# Processing Record 26 of Set 9 | plyussa
# Processing Record 27 of Set 9 | pochutla
# Processing Record 28 of Set 9 | senneterre
# Processing Record 29 of Set 9 | grand-santi
# Processing Record 30 of Set 9 | nemuro
# Processing Record 31 of Set 9 | ravels
# Processing Record 32 of Set 9 | teknaf
# Processing Record 33 of Set 9 | batagay-alyta
# City not found. Skipping...
# Processing Record 34 of Set 9 | olafsvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | katsuura
# Processing Record 36 of Set 9 | bahjoi
# Processing Record 37 of Set 9 | prabumulih
# Processing Record 38 of Set 9 | orlik
# Processing Record 39 of Set 9 | khatima
# Processing Record 40 of Set 9 | talnakh
# Processing Record 41 of Set 9 | dingle
# Processing Record 42 of Set 9 | surgut
# Processing Record 43 of Set 9 | bambanglipuro
# Processing Record 44 of Set 9 | kokstad
# Processing Record 45 of Set 9 | jalu
# Processing Record 46 of Set 9 | bud
# Processing Record 47 of Set 9 | chimbote
# Processing Record 48 of Set 9 | natal
# Processing Record 49 of Set 9 | sungaipenuh
# Processing Record 50 of Set 9 | kandrian
# Processing Record 0 of Set 10 | vadso
# Processing Record 1 of Set 10 | cap-chat
# Processing Record 2 of Set 10 | bowen
# Processing Record 3 of Set 10 | toba
# Processing Record 4 of Set 10 | mgandu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 10 | san jose
# Processing Record 6 of Set 10 | qaqortoq
# Processing Record 7 of Set 10 | rudnichnyy
# Processing Record 8 of Set 10 | tilichiki
# Processing Record 9 of Set 10 | ambulu
# Processing Record 10 of Set 10 | oda
# Processing Record 11 of Set 10 | weligama
# Processing Record 12 of Set 10 | palmeira
# Processing Record 13 of Set 10 | dukat
# City not found. Skipping...
# Processing Record 14 of Set 10 | mabaruma
# Processing Record 15 of Set 10 | at-bashi
# Processing Record 16 of Set 10 | giyani
# Processing Record 17 of Set 10 | wangqing
# Processing Record 18 of Set 10 | emmett
# Processing Record 19 of Set 10 | shumerlya
# Processing Record 20 of Set 10 | elko
# City not found. Skipping...
# Processing Record 21 of Set 10 | tezu
# Processing Record 22 of Set 10 | tabuk
# Processing Record 23 of Set 10 | smithers
# Processing Record 24 of Set 10 | shenzhen
# Processing Record 25 of Set 10 | chabahar
# Processing Record 26 of Set 10 | yerbogachen
# Processing Record 27 of Set 10 | rawson
# Processing Record 28 of Set 10 | tura
# Processing Record 29 of Set 10 | lanigay
# Processing Record 30 of Set 10 | atikokan
# Processing Record 31 of Set 10 | tulum
# City not found. Skipping...
# Processing Record 32 of Set 10 | naze
# Processing Record 33 of Set 10 | hoopstad
# Processing Record 34 of Set 10 | jacareacanga
# Processing Record 35 of Set 10 | kawalu
# Processing Record 36 of Set 10 | soe
# Processing Record 37 of Set 10 | bombay
# Processing Record 38 of Set 10 | asau
# Processing Record 39 of Set 10 | havoysund
# Processing Record 40 of Set 10 | tigil
# Processing Record 41 of Set 10 | conde
# Processing Record 42 of Set 10 | kemijarvi
# Processing Record 43 of Set 10 | baykit
# Processing Record 44 of Set 10 | touros
# Processing Record 45 of Set 10 | homer
# Processing Record 46 of Set 10 | iralaya
# Processing Record 47 of Set 10 | naqadeh
# Processing Record 48 of Set 10 | san-pedro
# Processing Record 49 of Set 10 | charters towers
# Processing Record 50 of Set 10 | sao pedro do sul
# Processing Record 0 of Set 11 | moree
# Processing Record 1 of Set 11 | marsh harbour
# Processing Record 2 of Set 11 | mahajanga
# Processing Record 3 of Set 11 | saravan
# Processing Record 4 of Set 11 | harrison
# Processing Record 5 of Set 11 | tskneti
# Processing Record 6 of Set 11 | mandera
# Processing Record 7 of Set 11 | namtsy
# Processing Record 8 of Set 11 | mount isa
# Processing Record 9 of Set 11 | hilton head island
# Processing Record 10 of Set 11 | garowe
# Processing Record 11 of Set 11 | rio grande
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | aracruz
# Processing Record 14 of Set 11 | belyy yar
# Processing Record 15 of Set 11 | mareeba
# Processing Record 16 of Set 11 | ilhabela
# Processing Record 17 of Set 11 | sao felix do xingu
# Processing Record 18 of Set 11 | serenje
# Processing Record 19 of Set 11 | san policarpo
# Processing Record 20 of Set 11 | san ramon
# Processing Record 21 of Set 11 | guiglo
# Processing Record 22 of Set 11 | virginia beach
# Processing Record 23 of Set 11 | hereford
# Processing Record 24 of Set 11 | gondar
# Processing Record 25 of Set 11 | rosario
# Processing Record 26 of Set 11 | obama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 11 | leningradskiy
# Processing Record 28 of Set 11 | agirish
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 11 | cap malheureux
# Processing Record 30 of Set 11 | nouadhibou
# Processing Record 31 of Set 11 | coquimbo
# City not found. Skipping...
# Processing Record 32 of Set 11 | saveh
# Processing Record 33 of Set 11 | dicabisagan
# Processing Record 34 of Set 11 | quemado de guines
# Processing Record 35 of Set 11 | lyngseidet
# Processing Record 36 of Set 11 | san fernando
# Processing Record 37 of Set 11 | chernyshevskiy
# Processing Record 38 of Set 11 | san juan
# Processing Record 39 of Set 11 | hollins
# Processing Record 40 of Set 11 | denizli
# Processing Record 41 of Set 11 | cajabamba
# Processing Record 42 of Set 11 | muisne
# Processing Record 43 of Set 11 | acapulco
# Processing Record 44 of Set 11 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 45 of Set 11 | nenjiang
# Processing Record 46 of Set 11 | orodara
# Processing Record 47 of Set 11 | hailey
# Processing Record 48 of Set 11 | otse
# Processing Record 49 of Set 11 | falakata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 11 | dubasari
# Processing Record 0 of Set 12 | cheney
# Processing Record 1 of Set 12 | bridlington
# Processing Record 2 of Set 12 | necochea
# Processing Record 3 of Set 12 | khandyga
# Processing Record 4 of Set 12 | tete
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Merging all API call information into a dataframe
city_df = pd.DataFrame({
    "City":city_list,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Humidity":humidity,
    "Cloudiness":cloud,
    "Wind Speed":wind_speed,
    "Country":country,
    "Date":date
})
city_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      carnarvon -24.87  113.63     23.00        64           8        5.70
# 1        rikitea -23.12 -134.97     22.54        81           0        8.55
# 2         barrow  71.29 -156.79      1.00        95          90        6.20
# 3         hasaki  35.73  140.83     19.00        88          20        2.60
# 4         castro -24.79  -50.01     22.61        51          84        2.23
# ..           ...    ...     ...       ...       ...         ...         ...
# 560       cheney  47.49 -117.58     15.00        72           1        2.10
# 561  bridlington  54.08   -0.19     13.89        93          96        6.20
# 562     necochea -38.55  -58.74      7.22        72           2        3.13
# 563     khandyga  62.67  135.60     -0.26        94          55        0.73
# 564         tete -16.16   33.59     36.00        30           4        3.60
#
#     Country        Date
# 0        AU  1601632325
# 1        PF  1601632325
# 2        US  1601632326
# 3        JP  1601632326
# 4        BR  1601632327
# ..      ...         ...
# 560      US  1601632626
# 561      GB  1601632626
# 562      AR  1601632626
# 563      RU  1601632627
# 564      MZ  1601632627
#
# [565 rows x 9 columns]

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    22.270159   23.230265   18.535965   70.541593   53.058407    3.808460
# std     31.269113   85.505813    9.953742   21.405336   37.730452    2.467934
# min    -54.800000 -175.200000   -7.310000    8.000000    0.000000    0.230000
# 25%     -3.320000  -49.220000   11.400000   60.000000   19.000000    2.100000
# 50%     22.810000   25.350000   19.600000   74.000000   58.000000    3.190000
# 75%     49.270000  100.340000   26.920000   87.000000   90.000000    5.080000
# max     78.220000  178.420000   39.850000  100.000000  100.000000   15.650000
#
#                Date
# count  5.650000e+02
# mean   1.601632e+09
# std    1.056944e+02
# min    1.601632e+09
# 25%    1.601632e+09
# 50%    1.601632e+09
# 75%    1.601633e+09
# max    1.601633e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking if humidity is greater than 100
humidity_check = city_df.loc[city_df['Humidity'] > 100]
humidity_check
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plotting Latitude vs Temperature
plt.scatter(city_df['Lat'],city_df['Max Temp'])
plt.title('City Latitude vs Max Temperature (30/09/20)')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('../Images/fig1.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plotting Latitude vs Humidity
plt.scatter(city_df['Lat'],city_df['Humidity'])
plt.title('City Latitude vs Humidity (30/09/20)')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('../Images/fig2.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plotting Latitude vs. Cloudiness
plt.scatter(city_df['Lat'],city_df['Cloudiness'])
plt.title('City Latitude vs Cloudiness (30/09/20)')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('../Images/fig3.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plotting Latitude vs. Wind Speed
plt.scatter(city_df['Lat'],city_df['Wind Speed'])
plt.title('City Latitude vs Wind Speed (30/09/20)')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('../Images/fig4.png')

# %%
# Extracting northern hemisphere only data from city dataframe
north_hemisphere = city_df.loc[city_df['Lat'] > 0]
north_hemisphere
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 2         barrow  71.29 -156.79      1.00        95          90        6.20
# 3         hasaki  35.73  140.83     19.00        88          20        2.60
# 5         kodiak  57.79 -152.41     11.00        87          90       11.30
# 7       suoyarvi  62.08   32.35     14.04        69          82        1.84
# 9           atar  20.52  -13.05     31.00        33           0        7.20
# ..           ...    ...     ...       ...       ...         ...         ...
# 558     falakata  26.52   89.21     32.66        64          98        2.49
# 559     dubasari  47.26   29.16     18.00        68          20        2.60
# 560       cheney  47.49 -117.58     15.00        72           1        2.10
# 561  bridlington  54.08   -0.19     13.89        93          96        6.20
# 563     khandyga  62.67  135.60     -0.26        94          55        0.73
#
#     Country        Date
# 2        US  1601632326
# 3        JP  1601632326
# 5        US  1601632278
# 7        RU  1601632328
# 9        MR  1601632329
# ..      ...         ...
# 558      IN  1601632624
# 559      MD  1601632625
# 560      US  1601632626
# 561      GB  1601632626
# 563      RU  1601632627
#
# [403 rows x 9 columns]

# %% [markdown]
# ## Linear Regression

# %%
# Linear Regression for Northern Hemisphere - Max Temp vs. Latitude Linear Regression
slope,intercept,rval,pval,std_err = stats.linregress(north_hemisphere['Lat'],north_hemisphere['Max Temp'])
fit = slope * north_hemisphere['Lat'] + intercept

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Scatterplot of Northern Hemisphere - Max Temp vs. Latitude Linear Regression
plt.scatter(north_hemisphere['Lat'],north_hemisphere['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.plot(north_hemisphere['Lat'],fit,color='red')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(10,0),fontsize=15,color="red")
print(f'The r-value is: {rval}')
# Out:
# The r-value is: -0.8100179766131349

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Extracting southern hemisphere only data from city dataframe
south_hemisphere = city_df.loc[city_df['Lat'] < 0]
south_hemisphere
# Out:
#                   City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            carnarvon -24.87  113.63     23.00        64           8
# 1              rikitea -23.12 -134.97     22.54        81           0
# 4               castro -24.79  -50.01     22.61        51          84
# 6               kabalo  -6.05   26.92     36.69        40          34
# 8              ushuaia -54.80  -68.30      0.00        90          75
# ..                 ...    ...     ...       ...       ...         ...
# 543  quemado de guines -20.57  -64.60     16.08        66          98
# 550          cajabamba  -7.62  -78.05     10.32        75           0
# 557               otse -25.02   25.73     27.00        44          40
# 562           necochea -38.55  -58.74      7.22        72           2
# 564               tete -16.16   33.59     36.00        30           4
#
#      Wind Speed Country        Date
# 0          5.70      AU  1601632325
# 1          8.55      PF  1601632325
# 4          2.23      BR  1601632327
# 6          0.48      CD  1601632327
# 8         12.90      AR  1601632328
# ..          ...     ...         ...
# 543        0.60      BO  1601632616
# 550        1.33      PE  1601632619
# 557        7.70      BW  1601632623
# 562        3.13      AR  1601632626
# 564        3.60      MZ  1601632627
#
# [162 rows x 9 columns]

# %%
# Linear Regression for Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
slope2,intercept2,rval2,pval2,std_err2 = stats.linregress(south_hemisphere['Lat'],south_hemisphere['Humidity'])
fit2 = slope2 * south_hemisphere['Lat'] + intercept2

# %%
# Scatterplot of Southern Hemisphere - Max Temp vs. Latitude Linear Regression
plt.scatter(south_hemisphere['Lat'],south_hemisphere['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')
plt.plot(south_hemisphere['Lat'],fit2,color='red')
line_eq2 = "y = " + str(round(slope2,2)) + "x + " + str(round(intercept2,2))
plt.annotate(line_eq2,(-50,20),fontsize=15,color="red")
print(f'The r-value is: {rval2}')
# Out:
# The r-value is: -0.045091775754668065

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
slope3,intercept3,rval3,pval3,std_err3 = stats.linregress(north_hemisphere['Lat'],north_hemisphere['Humidity'])
fit3 = slope3 * north_hemisphere['Lat'] + intercept3

# %%
# Scatterplot of Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(north_hemisphere['Lat'],north_hemisphere['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.plot(north_hemisphere['Lat'],fit3,color='red')
line_eq3 = "y = " + str(round(slope3,2)) + "x + " + str(round(intercept3,2))
plt.annotate(line_eq3,(45,25),fontsize=15,color="red")
print(f'The r-value is: {rval3}')
# Out:
# The r-value is: 0.1918469821717244

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
slope4,intercept4,rval4,pval4,std_err4 = stats.linregress(south_hemisphere['Lat'],south_hemisphere['Humidity'])
fit4 = slope4 * south_hemisphere['Lat'] + intercept4

# %%
# Scatterplot of Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(south_hemisphere['Lat'],south_hemisphere['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.plot(south_hemisphere['Lat'],fit4,color='red')
line_eq4 = "y = " + str(round(slope4,2)) + "x + " + str(round(intercept4,2))
plt.annotate(line_eq4,(-50,20),fontsize=15,color="red")
print(f'The r-value is: {rval4}')
# Out:
# The r-value is: -0.045091775754668065

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
slope5,intercept5,rval5,pval5,std_err5 = stats.linregress(north_hemisphere['Lat'],north_hemisphere['Cloudiness'])
fit5 = slope5 * north_hemisphere['Lat'] + intercept5

# %%
# Scatterplot of Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
plt.scatter(north_hemisphere['Lat'],north_hemisphere['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.plot(north_hemisphere['Lat'],fit5,color='red')
line_eq5 = "y = " + str(round(slope5,2)) + "x + " + str(round(intercept5,2))
plt.annotate(line_eq5,(45,45),fontsize=15,color="red")
print(f'The r-value is: {rval5}')
# Out:
# The r-value is: 0.18138694248421147

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
slope6,intercept6,rval6,pval6,std_err6 = stats.linregress(south_hemisphere['Lat'],south_hemisphere['Cloudiness'])
fit6 = slope6 * south_hemisphere['Lat'] + intercept6

# %%
# Scatterplot of Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
plt.scatter(south_hemisphere['Lat'],south_hemisphere['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.plot(south_hemisphere['Lat'],fit6,color='red')
line_eq6 = "y = " + str(round(slope6,2)) + "x + " + str(round(intercept6,2))
plt.annotate(line_eq6,(-50,20),fontsize=15,color="red")
print(f'The r-value is: {rval6}')
# Out:
# The r-value is: 0.22727681189312018

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
slope7,intercept7,rval7,pval7,std_err7 = stats.linregress(north_hemisphere['Lat'],north_hemisphere['Wind Speed'])
fit7 = slope7 * north_hemisphere['Lat'] + intercept7

# %%
# Scatterplot of Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
plt.scatter(north_hemisphere['Lat'],north_hemisphere['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.plot(north_hemisphere['Lat'],fit7,color='red')
line_eq7 = "y = " + str(round(slope7,2)) + "x + " + str(round(intercept7,2))
plt.annotate(line_eq7,(10,14),fontsize=15,color="red")
print(f'The r-value is: {rval7}')
# Out:
# The r-value is: 0.08148776951599576

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
slope8,intercept8,rval8,pval8,std_err8 = stats.linregress(south_hemisphere['Lat'],south_hemisphere['Wind Speed'])
fit8 = slope8 * south_hemisphere['Lat'] + intercept8

# %%
# Scatterplot of Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
plt.scatter(south_hemisphere['Lat'],south_hemisphere['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('South Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.plot(south_hemisphere['Lat'],fit8,color='red')
line_eq8 = "y = " + str(round(slope8,2)) + "x + " + str(round(intercept8,2))
plt.annotate(line_eq8,(-50,8),fontsize=15,color="red")
print(f'The r-value is: {rval8}')
# Out:
# The r-value is: -0.2957246020429039

# %%
# Observations
# We can observe in the scatterplot of Northern Hemisphere - Max Temp vs. Latitude Linear Regression, that the maximum
# temperature is higher in areas that are closest to the equater and the temperature decreases latitude coordinates increase

# It can be seen in the Latitude vs. Temperature Plot that the temperature is at its greatest towards the equator versus
# versus temperatures in the northern and southern hemisphere which is correct as temperatures tend to be hotter at the equator

# On the Latitude vs. Cloudiness Scatterplot there is no obvious trend or pattern, it can be seen that cloudiness has the largest
# variation compared to latitude vs other variables
